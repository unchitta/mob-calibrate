# %% [markdown]
# # Process mobility sequences
#
# The first step in this pipeline is to process timestamped mobility sample into sequences. The number of positions as well as the state labels should match that of the ATUS sequences that will be generated in `02_process_atus.ipynb`.
#
# Due to data policy, this notebook is intentionally left empty.
